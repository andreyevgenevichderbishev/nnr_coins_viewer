# %% [markdown]
# Это первый блокнот. Выполняется 1 раз.
# Результат изображения и html файлы слабов в PATH и файл base.txt в PATH

# %%
import requests
import string
import itertools
import concurrent.futures
import time
import os
import csv
from tqdm import tqdm
import pandas as pd
# Папка для сохранения
PATH = 'D:/Python/coin_pages'

# %% [markdown]
# ### Ишем номера существующих слабов.

# %% [markdown]
# Были замечены слабы только вида LLDDDD и позднее появились вида DLLDDD. Всего комбинаций данного вида $26\times 26\times 10000\simeq 6.8\times 10^6$ . На перебор всех комбинаций уходит около 2 суток.

# %%
# Создаем директорию для хранения страниц, если она не существует
os.makedirs(PATH, exist_ok=True)


#Генераторы номеров слабов. 
#0 - для слабов с номером вида DLLDDD 

def slab_number_generator_0(start_number):
    letters = string.ascii_uppercase
    digits = string.digits

    start_digit = start_number[0]
    start_letter1 = start_number[1].upper()
    start_letter2 = start_number[2].upper()
    start_digit_2 = start_number[3:]

    # Генерируем все возможные комбинации номеров слаба
    for digit in digits[digits.index(start_digit):]:
        for letter1 in letters if digit!=start_digit else letters[letters.index(start_letter1):]:
            for letter2 in letters:
                for digit_combination_2 in itertools.product(digits, repeat=3):
                    slab_number = f"{''.join(digit)}{letter1}{letter2}{''.join(digit_combination_2)}"
                    if slab_number >= start_number.upper():
                        yield slab_number
                        
#0 - для слабов с номером вида LLDDDD 
def slab_number_generator_1(start_number):
    letters = string.ascii_uppercase
    digits = string.digits

    start_letter1 = start_number[0].upper()
    start_letter2 = start_number[1].upper()
    start_digit = start_number[2:]

    # Генерируем все возможные комбинации номеров слаба
    for letter1 in letters[letters.index(start_letter1):]:
        for letter2 in letters if letter1 != start_letter1 else letters[letters.index(start_letter2):]:
            for digit_combination in itertools.product(digits, repeat=4):
                slab_number = f"{letter1}{letter2}{''.join(digit_combination)}"
                if slab_number >= start_number.upper():
                    yield slab_number


def check_file_exists(slab_number):
    url = f"https://nreestr.ru/img/all/bpict/{slab_number}r.jpg"
    try:
        response = requests.head(url)
        if response.status_code == 200:
            save_progress(f'{PATH}'+'/base.txt',f'{slab_number},')
        return response.status_code == 200
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return False

def save_progress(filename, name):
    with open(filename, 'a') as file:
        file.write(name)


def main(start_number):
    # Выбор диапазона слабов.
    slab_numbers = slab_number_generator_1(start_number)
#    slab_numbers = slab_number_generator_0(start_number)
    count = 0

    with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
        future_to_slab = {executor.submit(check_file_exists, slab_number): slab_number for slab_number in slab_numbers}

        for future in concurrent.futures.as_completed(future_to_slab):
            slab_number = future_to_slab[future]
            try:
                result = future.result()
                count += 1
                if count % 6000 == 0:
                    print(f"Processed {count} slab numbers")
            except Exception as exc:
                print(f"Slab number {slab_number} generated an exception: {exc}")
    print('Scanning complit')        

if __name__ == "__main__":
    start_number = input("Enter the starting slab number (e.g., vf0000): ").upper()
    main(start_number)
# Out:
# Enter the starting slab number (e.g., vf0000):  ZN6379
# An error occurred: HTTPSConnectionPool(host='nreestr.ru', port=443): Max retries exceeded with url: /img/all/bpict/ZO0547r.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001EBF207B7D0>, 'Connection to nreestr.ru timed out. (connect timeout=None)'))
# Processed 6000 slab numbers
# Processed 12000 slab numbers
# Processed 18000 slab numbers
# Processed 24000 slab numbers
# Processed 30000 slab numbers
# Processed 36000 slab numbers
# Processed 42000 slab numbers
# Processed 48000 slab numbers
# Processed 54000 slab numbers
# Processed 60000 slab numbers
# An error occurred: HTTPSConnectionPool(host='nreestr.ru', port=443): Max retries exceeded with url: /img/all/bpict/ZT8876r.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001EBFB367BD0>, 'Connection to nreestr.ru timed out. (connect timeout=None)'))
# Processed 66000 slab numbers
# Processed 72000 slab numbers
# Processed 78000 slab numbers
# Processed 84000 slab numbers
# Processed 90000 slab numbers
# Processed 96000 slab numbers
# Processed 102000 slab numbers
# Processed 108000 slab numbers
# Processed 114000 slab numbers
# Processed 120000 slab numbers
# An error occurred: HTTPSConnectionPool(host='nreestr.ru', port=443): Max retries exceeded with url: /img/all/bpict/ZZ7118r.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001EB83FD2710>, 'Connection to nreestr.ru timed out. (connect timeout=None)'))

# %% [markdown]
# Выводим первые 5 слабов.

# %%
with open('D:/Python/base.txt', 'r') as f:
    df = pd.DataFrame(f.read().split(','),columns=['number'])
print(df.head())
# Out:
#    number
# 0  AA0203
# 1  AA0509
# 2  AA0737
# 3  AA1075
# 4  AA1076

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121111 entries, 0 to 121110
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   number  121111 non-null  object
# dtypes: object(1)
# memory usage: 946.3+ KB

# %% [markdown]
# Проверка дубликатов

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Загружаем картинки и html страницы

# %%
def download_page(slab_number):
    url = f'https://nreestr.ru/coins/search/{slab_number}';
    try:
        response = requests.get(url)
        if response.status_code == 200:
            # Сохраняем страницу в файл
            filename = f"D:/Python/coin_pages/{slab_number}.html"
            with open(filename, 'w', encoding='utf-8') as file:
                file.write(response.text)
                
            url_r = f"https://nreestr.ru/img/all/bpict/{slab_number}r.jpg"  
            response = requests.get(url_r)   
            reversname = f"D:/Python/coin_pages/{slab_number}r.jpg"
            with open(reversname, 'wb') as file:
                file.write(response.content)    


            url_a = f"https://nreestr.ru/img/all/bpict/{slab_number}a.jpg"  
            response = requests.get(url_a)   
            reversname = f"D:/Python/coin_pages/{slab_number}a.jpg"
            with open(reversname, 'wb') as file:
                file.write(response.content)    

            
            time.sleep(0.2)    
            return f"Saved: {slab_number}"
        else:
            return f"Failed: {slab_number} (Status code: {response.status_code})"
    except Exception as e:
        return f"Error: {slab_number} ({e})"

count = 0

with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
    future_to_slab = {executor.submit(download_page, slab_number): slab_number for slab_number in df['number']}

    for future in concurrent.futures.as_completed(future_to_slab):
        slab_number = future_to_slab[future]
        try:
            result = future.result()
            count += 1
            if count % 200 == 0:
                print(f"Processed {count} slab numbers")
        except Exception as exc:
            print(f"Slab number {slab_number} generated an exception: {exc}")
    print('Dowloading complit')
# Out:
# Processed 200 slab numbers
# Processed 400 slab numbers
# Processed 600 slab numbers
# Processed 800 slab numbers
# Processed 1000 slab numbers
# Processed 1200 slab numbers
# Processed 1400 slab numbers
# Processed 1600 slab numbers
# Processed 1800 slab numbers
# Processed 2000 slab numbers
# Processed 2200 slab numbers
# Processed 2400 slab numbers
# Processed 2600 slab numbers
# Processed 2800 slab numbers
# Processed 3000 slab numbers
# Processed 3200 slab numbers
# Processed 3400 slab numbers
# Processed 3600 slab numbers
# Processed 3800 slab numbers
# Processed 4000 slab numbers
# Processed 4200 slab numbers
# Processed 4400 slab numbers
# Processed 4600 slab numbers
# Processed 4800 slab numbers
# Processed 5000 slab numbers
# Processed 5200 slab numbers
# Processed 5400 slab numbers
# Processed 5600 slab numbers
# Processed 5800 slab numbers
# Processed 6000 slab numbers
# Processed 6200 slab numbers
# Processed 6400 slab numbers
# Processed 6600 slab numbers
# Processed 6800 slab numbers
# Processed 7000 slab numbers
# Processed 7200 slab numbers
# Processed 7400 slab numbers
# Processed 7600 slab numbers
# Processed 7800 slab numbers
# Processed 8000 slab numbers
# Processed 8200 slab numbers
# Processed 8400 slab numbers
# Processed 8600 slab numbers
# Processed 8800 slab numbers
# Processed 9000 slab numbers
# Processed 9200 slab numbers
# Processed 9400 slab numbers
# Processed 9600 slab numbers
# Processed 9800 slab numbers
# Processed 10000 slab numbers
# Processed 10200 slab numbers
# Processed 10400 slab numbers
# Processed 10600 slab numbers
# Processed 10800 slab numbers
# Processed 11000 slab numbers
# Processed 11200 slab numbers
# Processed 11400 slab numbers
# Processed 11600 slab numbers
# Processed 11800 slab numbers
# Processed 12000 slab numbers
# Processed 12200 slab numbers
# Processed 12400 slab numbers
# Processed 12600 slab numbers
# Processed 12800 slab numbers
# Processed 13000 slab numbers
# Processed 13200 slab numbers
# Processed 13400 slab numbers
# Processed 13600 slab numbers
# Processed 13800 slab numbers
# Processed 14000 slab numbers
# Processed 14200 slab numbers
# Processed 14400 slab numbers
# Processed 14600 slab numbers
# Processed 14800 slab numbers
# Processed 15000 slab numbers
# Processed 15200 slab numbers
# Processed 15400 slab numbers
# Processed 15600 slab numbers
# Processed 15800 slab numbers
# Processed 16000 slab numbers
# Processed 16200 slab numbers
# Processed 16400 slab numbers
# Processed 16600 slab numbers
# Processed 16800 slab numbers
# Processed 17000 slab numbers
# Processed 17200 slab numbers
# Processed 17400 slab numbers
# Processed 17600 slab numbers
# Processed 17800 slab numbers
# Processed 18000 slab numbers
# Processed 18200 slab numbers
# Processed 18400 slab numbers
# Processed 18600 slab numbers
# Processed 18800 slab numbers
# Processed 19000 slab numbers
# Processed 19200 slab numbers
# Processed 19400 slab numbers
# Processed 19600 slab numbers
# Processed 19800 slab numbers
# Processed 20000 slab numbers
# Processed 20200 slab numbers
# Processed 20400 slab numbers
# Processed 20600 slab numbers
# Processed 20800 slab numbers
# Processed 21000 slab numbers
# Processed 21200 slab numbers
# Processed 21400 slab numbers
# Processed 21600 slab numbers
# Processed 21800 slab numbers
# Processed 22000 slab numbers
# Processed 22200 slab numbers
# Processed 22400 slab numbers
# Processed 22600 slab numbers
# Processed 22800 slab numbers
# Processed 23000 slab numbers
# Processed 23200 slab numbers
# Processed 23400 slab numbers
# Processed 23600 slab numbers
# Processed 23800 slab numbers
# Processed 24000 slab numbers
# Processed 24200 slab numbers
# Processed 24400 slab numbers
# Processed 24600 slab numbers
# Processed 24800 slab numbers
# Processed 25000 slab numbers
# Processed 25200 slab numbers
# Processed 25400 slab numbers
# Processed 25600 slab numbers
# Processed 25800 slab numbers
# Processed 26000 slab numbers
# Processed 26200 slab numbers
# Processed 26400 slab numbers
# Processed 26600 slab numbers
# Processed 26800 slab numbers
# Processed 27000 slab numbers
# Processed 27200 slab numbers
# Processed 27400 slab numbers
# Processed 27600 slab numbers
# Processed 27800 slab numbers
# Processed 28000 slab numbers
# Processed 28200 slab numbers
# Processed 28400 slab numbers
# Processed 28600 slab numbers
# Processed 28800 slab numbers
# Processed 29000 slab numbers
# Processed 29200 slab numbers
# Processed 29400 slab numbers
# Processed 29600 slab numbers
# Processed 29800 slab numbers
# Processed 30000 slab numbers
# Processed 30200 slab numbers
# Processed 30400 slab numbers
# Processed 30600 slab numbers
# Processed 30800 slab numbers
# Processed 31000 slab numbers
# Processed 31200 slab numbers
# Processed 31400 slab numbers
# Processed 31600 slab numbers
# Processed 31800 slab numbers
# Processed 32000 slab numbers
# Processed 32200 slab numbers
# Processed 32400 slab numbers
# Processed 32600 slab numbers
# Processed 32800 slab numbers
# Processed 33000 slab numbers
# Processed 33200 slab numbers
# Processed 33400 slab numbers
# Processed 33600 slab numbers
# Processed 33800 slab numbers
# Processed 34000 slab numbers
# Processed 34200 slab numbers
# Processed 34400 slab numbers
# Processed 34600 slab numbers
# Processed 34800 slab numbers
# Processed 35000 slab numbers
# Processed 35200 slab numbers
# Processed 35400 slab numbers
# Processed 35600 slab numbers
# Processed 35800 slab numbers
# Processed 36000 slab numbers
# Processed 36200 slab numbers
# Processed 36400 slab numbers
# Processed 36600 slab numbers
# Processed 36800 slab numbers
# Processed 37000 slab numbers
# Processed 37200 slab numbers
# Processed 37400 slab numbers
# Processed 37600 slab numbers
# Processed 37800 slab numbers
# Processed 38000 slab numbers
# Processed 38200 slab numbers
# Processed 38400 slab numbers
# Processed 38600 slab numbers
# Processed 38800 slab numbers
# Processed 39000 slab numbers
# Processed 39200 slab numbers
# Processed 39400 slab numbers
# Processed 39600 slab numbers
# Processed 39800 slab numbers
# Processed 40000 slab numbers
# Processed 40200 slab numbers
# Processed 40400 slab numbers
# Processed 40600 slab numbers
# Processed 40800 slab numbers
# Processed 41000 slab numbers
# Processed 41200 slab numbers
# Processed 41400 slab numbers
# Processed 41600 slab numbers
# Processed 41800 slab numbers
# Processed 42000 slab numbers
# Processed 42200 slab numbers
# Processed 42400 slab numbers
# Processed 42600 slab numbers
# Processed 42800 slab numbers
# Processed 43000 slab numbers
# Processed 43200 slab numbers
# Processed 43400 slab numbers
# Processed 43600 slab numbers
# Processed 43800 slab numbers
# Processed 44000 slab numbers
# Processed 44200 slab numbers
# Processed 44400 slab numbers
# Processed 44600 slab numbers
# Processed 44800 slab numbers
# Processed 45000 slab numbers
# Processed 45200 slab numbers
# Processed 45400 slab numbers
# Processed 45600 slab numbers
# Processed 45800 slab numbers
# Processed 46000 slab numbers
# Processed 46200 slab numbers
# Processed 46400 slab numbers
# Processed 46600 slab numbers
# Processed 46800 slab numbers
# Processed 47000 slab numbers
# Processed 47200 slab numbers
# Processed 47400 slab numbers
# Processed 47600 slab numbers
# Processed 47800 slab numbers
# Processed 48000 slab numbers
# Processed 48200 slab numbers
# Processed 48400 slab numbers
# Processed 48600 slab numbers
# Processed 48800 slab numbers
# Processed 49000 slab numbers
# Processed 49200 slab numbers
# Processed 49400 slab numbers
# Processed 49600 slab numbers
# Processed 49800 slab numbers
# Processed 50000 slab numbers
# Processed 50200 slab numbers
# Processed 50400 slab numbers
# Processed 50600 slab numbers
# Processed 50800 slab numbers
# Processed 51000 slab numbers
# Processed 51200 slab numbers
# Processed 51400 slab numbers
# Processed 51600 slab numbers
# Processed 51800 slab numbers
# Processed 52000 slab numbers
# Processed 52200 slab numbers
# Processed 52400 slab numbers
# Processed 52600 slab numbers
# Processed 52800 slab numbers
# Processed 53000 slab numbers
# Processed 53200 slab numbers
# Processed 53400 slab numbers
# Processed 53600 slab numbers
# Processed 53800 slab numbers
# Processed 54000 slab numbers
# Processed 54200 slab numbers
# Processed 54400 slab numbers
# Processed 54600 slab numbers
# Processed 54800 slab numbers
# Processed 55000 slab numbers
# Processed 55200 slab numbers
# Processed 55400 slab numbers
# Processed 55600 slab numbers
# Processed 55800 slab numbers
# Processed 56000 slab numbers
# Processed 56200 slab numbers
# Processed 56400 slab numbers
# Processed 56600 slab numbers
# Processed 56800 slab numbers
# Processed 57000 slab numbers
# Processed 57200 slab numbers
# Processed 57400 slab numbers
# Processed 57600 slab numbers
# Processed 57800 slab numbers
# Processed 58000 slab numbers
# Processed 58200 slab numbers
# Processed 58400 slab numbers
# Processed 58600 slab numbers
# Processed 58800 slab numbers
# Processed 59000 slab numbers
# Processed 59200 slab numbers
# Processed 59400 slab numbers
# Processed 59600 slab numbers
# Processed 59800 slab numbers
# Processed 60000 slab numbers
# Processed 60200 slab numbers
# Processed 60400 slab numbers
# Processed 60600 slab numbers
# Processed 60800 slab numbers
# Processed 61000 slab numbers
# Processed 61200 slab numbers
# Processed 61400 slab numbers
# Processed 61600 slab numbers
# Processed 61800 slab numbers
# Processed 62000 slab numbers
# Processed 62200 slab numbers
# Processed 62400 slab numbers
# Processed 62600 slab numbers
# Processed 62800 slab numbers
# Processed 63000 slab numbers
# Processed 63200 slab numbers
# Processed 63400 slab numbers
# Processed 63600 slab numbers
# Processed 63800 slab numbers
# Processed 64000 slab numbers
# Processed 64200 slab numbers
# Processed 64400 slab numbers
# Processed 64600 slab numbers
# Processed 64800 slab numbers
# Processed 65000 slab numbers
# Processed 65200 slab numbers
# Processed 65400 slab numbers
# Processed 65600 slab numbers
# Processed 65800 slab numbers
# Processed 66000 slab numbers
# Processed 66200 slab numbers
# Processed 66400 slab numbers
# Processed 66600 slab numbers
# Processed 66800 slab numbers
# Processed 67000 slab numbers
# Processed 67200 slab numbers
# Processed 67400 slab numbers
# Processed 67600 slab numbers
# Processed 67800 slab numbers
# Processed 68000 slab numbers
# Processed 68200 slab numbers
# Processed 68400 slab numbers
# Processed 68600 slab numbers
# Processed 68800 slab numbers
# Processed 69000 slab numbers
# Processed 69200 slab numbers
# Processed 69400 slab numbers
# Processed 69600 slab numbers
# Processed 69800 slab numbers
# Processed 70000 slab numbers
# Processed 70200 slab numbers
# Processed 70400 slab numbers
# Processed 70600 slab numbers
# Processed 70800 slab numbers
# Processed 71000 slab numbers
# Processed 71200 slab numbers
# Processed 71400 slab numbers
# Processed 71600 slab numbers
# Processed 71800 slab numbers
# Processed 72000 slab numbers
# Processed 72200 slab numbers
# Processed 72400 slab numbers
# Processed 72600 slab numbers
# Processed 72800 slab numbers
# Processed 73000 slab numbers
# Processed 73200 slab numbers
# Processed 73400 slab numbers
# Processed 73600 slab numbers
# Processed 73800 slab numbers
# Processed 74000 slab numbers
# Processed 74200 slab numbers
# Processed 74400 slab numbers
# Processed 74600 slab numbers
# Processed 74800 slab numbers
# Processed 75000 slab numbers
# Processed 75200 slab numbers
# Processed 75400 slab numbers
# Processed 75600 slab numbers
# Processed 75800 slab numbers
# Processed 76000 slab numbers
# Processed 76200 slab numbers
# Processed 76400 slab numbers
# Processed 76600 slab numbers
# Processed 76800 slab numbers
# Processed 77000 slab numbers
# Processed 77200 slab numbers
# Processed 77400 slab numbers
# Processed 77600 slab numbers
# Processed 77800 slab numbers
# Processed 78000 slab numbers
# Processed 78200 slab numbers
# Processed 78400 slab numbers
# Processed 78600 slab numbers
# Processed 78800 slab numbers
# Processed 79000 slab numbers
# Processed 79200 slab numbers
# Processed 79400 slab numbers
# Processed 79600 slab numbers
# Processed 79800 slab numbers
# Processed 80000 slab numbers
# Processed 80200 slab numbers
# Processed 80400 slab numbers
# Processed 80600 slab numbers
# Processed 80800 slab numbers
# Processed 81000 slab numbers
# Processed 81200 slab numbers
# Processed 81400 slab numbers
# Processed 81600 slab numbers
# Processed 81800 slab numbers
# Processed 82000 slab numbers
# Processed 82200 slab numbers
# Processed 82400 slab numbers
# Processed 82600 slab numbers
# Processed 82800 slab numbers
# Processed 83000 slab numbers
# Processed 83200 slab numbers
# Processed 83400 slab numbers
# Processed 83600 slab numbers
# Processed 83800 slab numbers
# Processed 84000 slab numbers
# Processed 84200 slab numbers
# Processed 84400 slab numbers
# Processed 84600 slab numbers
# Processed 84800 slab numbers
# Processed 85000 slab numbers
# Processed 85200 slab numbers
# Processed 85400 slab numbers
# Processed 85600 slab numbers
# Processed 85800 slab numbers
# Processed 86000 slab numbers
# Processed 86200 slab numbers
# Processed 86400 slab numbers
# Processed 86600 slab numbers
# Processed 86800 slab numbers
# Processed 87000 slab numbers
# Processed 87200 slab numbers
# Processed 87400 slab numbers
# Processed 87600 slab numbers
# Processed 87800 slab numbers
# Processed 88000 slab numbers
# Processed 88200 slab numbers
# Processed 88400 slab numbers
# Processed 88600 slab numbers
# Processed 88800 slab numbers
# Processed 89000 slab numbers
# Processed 89200 slab numbers
# Processed 89400 slab numbers
# Processed 89600 slab numbers
# Processed 89800 slab numbers
# Processed 90000 slab numbers
# Processed 90200 slab numbers
# Processed 90400 slab numbers
# Processed 90600 slab numbers
# Processed 90800 slab numbers
# Processed 91000 slab numbers
# Processed 91200 slab numbers
# Processed 91400 slab numbers
# Processed 91600 slab numbers
# Processed 91800 slab numbers
# Processed 92000 slab numbers
# Processed 92200 slab numbers
# Processed 92400 slab numbers
# Processed 92600 slab numbers
# Processed 92800 slab numbers
# Processed 93000 slab numbers
# Processed 93200 slab numbers
# Processed 93400 slab numbers
# Processed 93600 slab numbers
# Processed 93800 slab numbers
# Processed 94000 slab numbers
# Processed 94200 slab numbers
# Processed 94400 slab numbers
# Processed 94600 slab numbers
# Processed 94800 slab numbers
# Processed 95000 slab numbers
# Processed 95200 slab numbers
# Processed 95400 slab numbers
# Processed 95600 slab numbers
# Processed 95800 slab numbers
# Processed 96000 slab numbers
# Processed 96200 slab numbers
# Processed 96400 slab numbers
# Processed 96600 slab numbers
# Processed 96800 slab numbers
# Processed 97000 slab numbers
# Processed 97200 slab numbers
# Processed 97400 slab numbers
# Processed 97600 slab numbers
# Processed 97800 slab numbers
# Processed 98000 slab numbers
# Processed 98200 slab numbers
# Processed 98400 slab numbers
# Processed 98600 slab numbers
# Processed 98800 slab numbers
# Processed 99000 slab numbers
# Processed 99200 slab numbers
# Processed 99400 slab numbers
# Processed 99600 slab numbers
# Processed 99800 slab numbers
# Processed 100000 slab numbers
# Processed 100200 slab numbers
# Processed 100400 slab numbers
# Processed 100600 slab numbers
# Processed 100800 slab numbers
# Processed 101000 slab numbers
# Processed 101200 slab numbers
# Processed 101400 slab numbers
# Processed 101600 slab numbers
# Processed 101800 slab numbers
# Processed 102000 slab numbers
# Processed 102200 slab numbers
# Processed 102400 slab numbers
# Processed 102600 slab numbers
# Processed 102800 slab numbers
# Processed 103000 slab numbers
# Processed 103200 slab numbers
# Processed 103400 slab numbers
# Processed 103600 slab numbers
# Processed 103800 slab numbers
# Processed 104000 slab numbers
# Processed 104200 slab numbers
# Processed 104400 slab numbers
# Processed 104600 slab numbers
# Processed 104800 slab numbers
# Processed 105000 slab numbers
# Processed 105200 slab numbers
# Processed 105400 slab numbers
# Processed 105600 slab numbers
# Processed 105800 slab numbers
# Processed 106000 slab numbers
# Processed 106200 slab numbers
# Processed 106400 slab numbers
# Processed 106600 slab numbers
# Processed 106800 slab numbers
# Processed 107000 slab numbers
# Processed 107200 slab numbers
# Processed 107400 slab numbers
# Processed 107600 slab numbers
# Processed 107800 slab numbers
# Processed 108000 slab numbers
# Processed 108200 slab numbers
# Processed 108400 slab numbers
# Processed 108600 slab numbers
# Processed 108800 slab numbers
# Processed 109000 slab numbers
# Processed 109200 slab numbers
# Processed 109400 slab numbers
# Processed 109600 slab numbers
# Processed 109800 slab numbers
# Processed 110000 slab numbers
# Processed 110200 slab numbers
# Processed 110400 slab numbers
# Processed 110600 slab numbers
# Processed 110800 slab numbers
# Processed 111000 slab numbers
# Processed 111200 slab numbers
# Processed 111400 slab numbers
# Processed 111600 slab numbers
# Processed 111800 slab numbers
# Processed 112000 slab numbers
# Processed 112200 slab numbers
# Processed 112400 slab numbers
# Processed 112600 slab numbers
# Processed 112800 slab numbers
# Processed 113000 slab numbers
# Processed 113200 slab numbers
# Processed 113400 slab numbers
# Processed 113600 slab numbers
# Processed 113800 slab numbers
# Processed 114000 slab numbers
# Processed 114200 slab numbers
# Processed 114400 slab numbers
# Processed 114600 slab numbers
# Processed 114800 slab numbers
# Processed 115000 slab numbers
# Processed 115200 slab numbers
# Processed 115400 slab numbers
# Processed 115600 slab numbers
# Processed 115800 slab numbers
# Processed 116000 slab numbers
# Processed 116200 slab numbers
# Processed 116400 slab numbers
# Processed 116600 slab numbers
# Processed 116800 slab numbers
# Processed 117000 slab numbers
# Processed 117200 slab numbers
# Processed 117400 slab numbers
# Processed 117600 slab numbers
# Processed 117800 slab numbers
# Processed 118000 slab numbers
# Processed 118200 slab numbers
# Processed 118400 slab numbers
# Processed 118600 slab numbers
# Processed 118800 slab numbers
# Processed 119000 slab numbers
# Processed 119200 slab numbers
# Processed 119400 slab numbers
# Processed 119600 slab numbers
# Processed 119800 slab numbers
# Processed 120000 slab numbers
# Processed 120200 slab numbers
# Processed 120400 slab numbers
# Processed 120600 slab numbers
# Processed 120800 slab numbers
# Processed 121000 slab numbers
